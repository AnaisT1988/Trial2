# %% [markdown]
# # Bayesian Optimization of a Buchwald Reaction
#
# Jason Stevens & Ben Shields

# %% [markdown]
# ## Buchwald Reaction

# %%
from rdkit.Chem import AllChem, Draw

rxn = AllChem.ReactionFromSmarts('CC1=CC=C(N)C=C1.[F,Cl,Br,I]C1=CC=CC=C1>>CC1=CC=C(NC2=CC=CC=C2)C=C1')
Draw.ReactionToImage(rxn, subImgSize=(250, 250))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1000x250>

# %% [markdown]
# ## Defining the Reaction Space
#
# We included 4 optimization parameters for this reaction:
# 1. aryl halide (15)
# 2. Pd Catalyst (4)
# 3. Additive (16)
# 4. Base (3)
#
#
# ## Reaction Encoding
#
# In keeping with our paper, we are going to use DFT encoding for all categorical chemical parameters and numerical encoding for continuous parameters.
#
# For the continuous parameters we will define our own discrete grid. On the technical side this is because we are going to explicitly take the $argmax$ of our acquisition function over the search space rather than run an optimization algorithm. I will add support for optimization algorithms down the line though this is practical up to millions of data points. However, it does require some care in the selection of grid points ($10^9$ points in the search space will take quite a while to compute). So, take some time to think about what is reasonable (i.e. there is no point in including 30 and 30.5 as temperatures if your stir plate varies by (+/-) 1 degree. Here we use a course but reasonable grid which gives a search space of $14 * 4 * 16 * 3 = 2,688$ possible points.
#
# Let's start by loading the precomputed DFT chemical descriptor matrices. We will use an EDBO data utility (```edbo.utils.Data```) to clean up the descriptor sets a bit by removing some unwanted descriptors.

# %%
# Imports

import pandas as pd
from edbo.utils import Data

# Load DFT descriptor CSV files computed with auto-qchem using pandas
# Instantiate a Data object

aryl_halid = Data(pd.read_csv('descriptors/aryl_halide_dft.csv'))
additive = Data(pd.read_csv('descriptors/additive_dft.csv'))
base = Data(pd.read_csv('descriptors/base_dft.csv'))
ligand = Data(pd.read_csv('descriptors/ligand-Pd(0)_dft.csv'))

# Use Data.drop method to drop descriptors containing some unwanted keywords

for data in [aryl_halid, additive, base,ligand]:
    data.drop(['file_name', 'entry', 'vibration', 'correlation', 'Rydberg', 
               'correction', 'atom_number', 'E-M_angle', 'MEAN', 'MAXG', 
               'STDEV'])

# %% [markdown]
# Here are what the descriptor sets look like before preprocessing.

# %%
aryl_halid.data
# Out:
#    aryl_halide_CAS_Number    aryl_halide_SMILES aryl_halide_stoichiometry  \
# 0               1585-07-5        CCc1ccc(Br)cc1                    C8H9Br
# 1                104-92-7        COc1ccc(Br)cc1                   C7H7BrO
# 2                402-43-7  FC(F)(F)c1ccc(Br)cc1                  C7H4BrF3
# 3                622-98-0        CCc1ccc(Cl)cc1                    C8H9Cl
# 4                623-12-1        COc1ccc(Cl)cc1                   C7H7ClO
# 5                 98-56-6  FC(F)(F)c1ccc(Cl)cc1                  C7H4ClF3
# 6              25309-64-2         CCc1ccc(I)cc1                     C8H9I
# 7                696-62-8         COc1ccc(I)cc1                    C7H7IO
# 8                455-13-0   FC(F)(F)c1ccc(I)cc1                   C7H4F3I
# 9                109-04-6            Brc1ccccn1                   C5H4BrN
# 10               109-09-1            Clc1ccccn1                   C5H4ClN
# 11              5029-67-4             Ic1ccccn1                    C5H4IN
# 12               626-55-1            Brc1cccnc1                   C5H4BrN
# 13               626-60-8            Clc1cccnc1                   C5H4ClN
# 14              1120-90-7             Ic1cccnc1                    C5H4IN
#
#     aryl_halide_number_of_atoms  aryl_halide_charge  aryl_halide_multiplicity  \
# 0                            18                   0                         1
# 1                            16                   0                         1
# 2                            15                   0                         1
# 3                            18                   0                         1
# 4                            16                   0                         1
# 5                            15                   0                         1
# 6                            18                   0                         1
# 7                            16                   0                         1
# 8                            15                   0                         1
# 9                            11                   0                         1
# 10                           11                   0                         1
# 11                           11                   0                         1
# 12                           11                   0                         1
# 13                           11                   0                         1
# 14                           11                   0                         1
#
#    aryl_halide_convergence_criteria  aryl_halide_dipole  \
# 0                            failed              2.2354
# 1                               met              2.8189
# 2                               met              0.9239
# 3                            failed              2.3291
# 4                               met              2.8944
# 5                               met              0.7724
# 6                            failed              2.2853
# 7                               met              2.8584
# 8                               met              0.9325
# 9                               met              3.4076
# 10                              met              3.5201
# 11                              met              3.5586
# 12                              met              2.0317
# 13                              met              2.0883
# 14                              met              2.0313
#
#     aryl_halide_molar_mass  aryl_halide_molar_volume  ...  \
# 0                 185.0631                  1127.232  ...
# 1                 187.0357                  1252.026  ...
# 2                 225.0078                  1189.300  ...
# 3                 140.6121                  1486.540  ...
# 4                 142.5847                  1098.721  ...
# 5                 180.5568                  1319.233  ...
# 6                 232.0636                  1189.984  ...
# 7                 234.0362                  1222.020  ...
# 8                 272.0083                  1095.191  ...
# 9                 157.9973                  1036.930  ...
# 10                113.5463                   830.234  ...
# 11                204.9978                  1050.645  ...
# 12                157.9973                   652.969  ...
# 13                113.5463                   987.175  ...
# 14                204.9978                  1080.254  ...
#
#     aryl_halide_atom2_%VBur  aryl_halide_atom3_%VBur  aryl_halide_atom4_%VBur  \
# 0                  0.627915                 0.538008                 0.556181
# 1                  0.628364                 0.539894                 0.569743
# 2                  0.629113                 0.538487                 0.561480
# 3                  0.614263                 0.533607                 0.555253
# 4                  0.613934                 0.535403                 0.570252
# 5                  0.614862                 0.534176                 0.561480
# 6                  0.649352                 0.545732                 0.556211
# 7                  0.649172                 0.547708                 0.570163
# 8                  0.650519                 0.546541                 0.561839
# 9                  0.609862                 0.535762                 0.499266
# 10                 0.595312                 0.531511                 0.499386
# 11                 0.631029                 0.543487                 0.499506
# 12                 0.625191                 0.534834                 0.497680
# 13                 0.610610                 0.530403                 0.497350
# 14                 0.647136                 0.542678                 0.497440
#
#     aryl_halide_atom5_%VBur  aryl_halide_atom6_%VBur  aryl_halide_atom7_%VBur  \
# 0                  0.667315                 0.382863                 0.402533
# 1                  0.623933                 0.384150                 0.442831
# 2                  0.681267                 0.383851                 0.416185
# 3                  0.667166                 0.377025                 0.402114
# 4                  0.624293                 0.378132                 0.443789
# 5                  0.681297                 0.377354                 0.416305
# 6                  0.667196                 0.394300                 0.403251
# 7                  0.624023                 0.395677                 0.442801
# 8                  0.681536                 0.395228                 0.416155
# 9                  0.496871                 0.381965                 0.338014
# 10                 0.496871                 0.375588                 0.337954
# 11                 0.496752                 0.394210                 0.338493
# 12                 0.482800                 0.379809                 0.337804
# 13                 0.482830                 0.373941                 0.337625
# 14                 0.482560                 0.390647                 0.337744
#
#     aryl_halide_c_min_%VBur  aryl_halide_c_min+1_%VBur  \
# 0                  0.429897                   0.551151
# 1                  0.514056                   0.569743
# 2                  0.407922                   0.424179
# 3                  0.430227                   0.551061
# 4                  0.514236                   0.570252
# 5                  0.407982                   0.424059
# 6                  0.430436                   0.551241
# 7                  0.514416                   0.570163
# 8                  0.407922                   0.424029
# 9                  0.514925                   0.535762
# 10                 0.510045                   0.531511
# 11                 0.523727                   0.543487
# 12                 0.471692                   0.497680
# 13                 0.471573                   0.497350
# 14                 0.472171                   0.497440
#
#     aryl_halide_c_max_%VBur  aryl_halide_c_max-1_%VBur
# 0                  0.382863                   0.382743
# 1                  0.623933                   0.382863
# 2                  0.567498                   0.383821
# 3                  0.377025                   0.376725
# 4                  0.624293                   0.377025
# 5                  0.567079                   0.377414
# 6                  0.394300                   0.394120
# 7                  0.624023                   0.394090
# 8                  0.567348                   0.395228
# 9                  0.609862                   0.381965
# 10                 0.595312                   0.375588
# 11                 0.631029                   0.394210
# 12                 0.379809                   0.368821
# 13                 0.373941                   0.363073
# 14                 0.390647                   0.380378
#
# [15 rows x 324 columns]

# %%
additive.data
# Out:
#    additive_CAS_Number          additive_SMILES additive_stoichiometry  \
# 0             300-87-8              Cc1onc(C)c1                 C5H7NO
# 1            1008-75-9       Cc1cc(on1)c2ccccc2                C10H9NO
# 2           30842-90-1                 Cc1ccon1                 C4H5NO
# 3            1006-65-1        o1ccc(n1)c2ccccc2                 C9H7NO
# 4            5765-44-6                 Cc1oncc1                 C4H5NO
# 5            1006-67-3          o1nccc1c2ccccc2                 C9H7NO
# 6             271-58-9            o1cc2ccccc2n1                 C7H5NO
# 7             271-95-4            o1ncc2ccccc12                 C7H5NO
# 8           63366-79-0       CCOC(=O)c1onc(C)c1                C7H9NO3
# 9            3209-72-1       CCOC(=O)c1cc(C)on1                C7H9NO3
# 10          51135-73-0         CCOC(=O)c1cnoc1C                C7H9NO3
# 11           3209-70-9          CCOC(=O)c1ccon1                C6H7NO3
# 12          80370-40-7          CCOC(=O)c1conc1                C6H7NO3
# 13          33545-41-4  COC(=O)c1cc(on1)c2occc2                C9H7NO4
# 14         517870-23-4  COC(=O)c1cc(on1)c2sccc2               C9H7NO3S
# 15          15055-81-9           COC(=O)c1oncc1                C5H5NO3
#
#     additive_number_of_atoms  additive_charge  additive_multiplicity  \
# 0                         14                0                      1
# 1                         21                0                      1
# 2                         11                0                      1
# 3                         18                0                      1
# 4                         11                0                      1
# 5                         18                0                      1
# 6                         14                0                      1
# 7                         14                0                      1
# 8                         20                0                      1
# 9                         20                0                      1
# 10                        20                0                      1
# 11                        17                0                      1
# 12                        17                0                      1
# 13                        21                0                      1
# 14                        21                0                      1
# 15                        14                0                      1
#
#    additive_convergence_criteria  additive_dipole  additive_molar_mass  \
# 0                            met           3.0974              97.1164
# 1                            met           3.0255             159.1872
# 2                            met           2.9785              83.0896
# 3                            met           2.7531             145.1604
# 4                            met           3.2041              83.0896
# 5                            met           3.2104             145.1604
# 6                            met           3.1967             119.1226
# 7                            met           3.1821             119.1226
# 8                            met           1.1907             155.1530
# 9                            met           1.4543             155.1530
# 10                           met           2.3358             155.1530
# 11                           met           1.0440             141.1262
# 12                           met           3.4406             141.1262
# 13                           met           1.9636             193.1586
# 14                           met           1.8227             209.2192
# 15                           met           1.2659             127.0994
#
#     additive_molar_volume  ...  additive_c_max-1_ES_root_NPA_total  \
# 0                 820.844  ...                             5.98141
# 1                1506.272  ...                             5.85771
# 2                 718.799  ...                             6.00004
# 3                1127.009  ...                             5.87931
# 4                 674.794  ...                             0.75523
# 5                1341.570  ...                             0.74837
# 6                1000.787  ...                             0.76504
# 7                 988.047  ...                             0.75586
# 8                1102.104  ...                             5.85133
# 9                1360.550  ...                             5.68047
# 10               1174.194  ...                             5.71181
# 11                961.379  ...                             0.75036
# 12               1164.761  ...                             5.93370
# 13               1551.408  ...                             5.81988
# 14               1532.373  ...                             5.76889
# 15                985.887  ...                             5.85595
#
#     additive_atom1_%VBur  additive_atom2_%VBur  additive_atom3_%VBur  \
# 0               0.475674              0.465375              0.585462
# 1               0.510104              0.467411              0.585462
# 2               0.429418              0.466513              0.585042
# 3               0.430017              0.498428              0.632795
# 4               0.475824              0.421963              0.457920
# 5               0.510194              0.423610              0.457441
# 6               0.432113              0.451693              0.617856
# 7               0.458549              0.424119              0.476393
# 8               0.488009              0.466124              0.584234
# 9               0.475704              0.477800              0.608126
# 10              0.475824              0.421185              0.502500
# 11              0.429688              0.478339              0.608485
# 12              0.429299              0.422143              0.496063
# 13              0.493039              0.478129              0.608724
# 14              0.502440              0.479028              0.608874
# 15              0.488309              0.422682              0.456932
#
#     additive_atom4_%VBur  additive_atom5_%VBur  additive_c_min_%VBur  \
# 0               0.526122              0.580522              0.399479
# 1               0.550942              0.628724              0.403910
# 2               0.496362              0.451933              0.403281
# 3               0.523787              0.451873              0.430017
# 4               0.495105              0.579114              0.399539
# 5               0.519895              0.628095              0.510194
# 6               0.626867              0.472740              0.432113
# 7               0.628394              0.616239              0.458549
# 8               0.537110              0.602497              0.569833
# 9               0.537679              0.579025              0.569294
# 10              0.644771              0.618125              0.581330
# 11              0.508548              0.451154              0.568905
# 12              0.618484              0.498728              0.576899
# 13              0.550133              0.605162              0.522290
# 14              0.555941              0.618814              0.522320
# 15              0.506721              0.603066              0.523487
#
#     additive_c_min+1_%VBur  additive_c_max_%VBur  additive_c_max-1_%VBur
# 0                 0.403281              0.580522                0.585462
# 1                 0.510104              0.628724                0.585462
# 2                 0.429418              0.585042                0.451933
# 3                 0.523787              0.632795                0.451873
# 4                 0.475824              0.579114                0.339990
# 5                 0.519895              0.628095                0.378581
# 6                 0.451693              0.617856                0.319901
# 7                 0.503428              0.616239                0.326547
# 8                 0.450016              0.579923                0.584234
# 9                 0.456124              0.584324                0.579025
# 10                0.486393              0.604892                0.618125
# 11                0.455705              0.583935                0.363253
# 12                0.451543              0.584713                0.498728
# 13                0.432861              0.563875                0.605162
# 14                0.433251              0.563516                0.618814
# 15                0.426754              0.558875                0.603066
#
# [16 rows x 200 columns]

# %%
base.data
# Out:
#   base_CAS_Number                                base_SMILES  \
# 0      29166-72-1                  CN(C)/C(N(C)C)=N\C(C)(C)C
# 1      84030-20-6                           CN1CCCN2CCCN=C12
# 2     165535-45-5  CN(C)P(N(C)C)(N(C)C)=NP(N(C)C)(N(C)C)=NCC
#
#   base_stoichiometry  base_number_of_atoms  base_charge  base_multiplicity  \
# 0            C9H21N3                    33            0                  1
# 1            C8H15N3                    26            0                  1
# 2         C12H35N7P2                    56            0                  1
#
#   base_convergence_criteria  base_dipole  base_molar_mass  base_molar_volume  \
# 0                       met       2.1551         171.2850           1893.291
# 1                       met       2.7037         153.2266           1347.320
# 2                    failed       5.2402         339.4029           2403.886
#
#    ...  base_c_max-1_ES_root_Mulliken_charge  base_c_max-1_ES_root_NPA_charge  \
# 0  ...                              0.189141                          0.09787
# 1  ...                              0.168928                          0.24020
# 2  ...                              1.177130                          2.33476
#
#    base_c_max-1_ES_root_NPA_core  base_c_max-1_ES_root_NPA_valence  \
# 0                        1.99908                           3.88405
# 1                        0.00000                           0.75879
# 2                        9.99756                           2.53937
#
#    base_c_max-1_ES_root_NPA_total  base_atom1_%VBur  base_c_min_%VBur  \
# 0                         5.90213          0.723392          0.723392
# 1                         0.75980          0.590192          0.590192
# 2                        12.66524          0.721416          0.819077
#
#    base_c_min+1_%VBur  base_c_max_%VBur  base_c_max-1_%VBur
# 0            0.773390          0.762492            0.779108
# 1            0.682405          0.697614            0.390527
# 2            0.721416          0.845394            0.835604
#
# [3 rows x 136 columns]

# %%
ligand.data
# Out:
#   Pd(0)-ligand_CAS_Number                                      ligand_SMILES  \
# 0            1445972-29-1  CC(C1=C(C2=C(OC)C=CC(OC)=C2P(C34CC5CC(C4)CC(C5...
# 1            1536473-72-9  CC(C)C1=CC(C(C)C)=CC(C(C)C)=C1C2=C(P(C(C)(C)C)...
# 2            1447963-75-8  CC(C)C(C=C(C(C)C)C=C1C(C)C)=C1C2=CC=CC=C2P(C(C...
# 3            1445085-55-1  CC(C)C1=CC(C(C)C)=CC(C(C)C)=C1C2=C(P(C3CCCCC3)...
#
#   Pd(0)-ligand_stoichiometry  Pd(0)-ligand_number_of_atoms  \
# 0                C43H61O2PPd                           108
# 1                C31H49O2PPd                            84
# 2                  C29H45PPd                            76
# 3                  C33H49PPd                            84
#
#    Pd(0)-ligand_charge  Pd(0)-ligand_multiplicity  \
# 0                    0                          1
# 1                    0                          1
# 2                    0                          1
# 3                    0                          1
#
#   Pd(0)-ligand_convergence_criteria  Pd(0)-ligand_dipole  \
# 0                               met               4.7110
# 1                            failed               4.8634
# 2                            failed               2.0369
# 3                               met               2.1453
#
#    Pd(0)-ligand_molar_mass  Pd(0)-ligand_molar_volume  ...  \
# 0                 747.3275                   5808.171  ...
# 1                 591.1007                   3694.362  ...
# 2                 531.0483                   4817.802  ...
# 3                 583.1239                   5062.880  ...
#
#    Pd(0)-ligand_vib_42_standard_dip_strength  \
# 0                                      90.65
# 1                                      90.65
# 2                                      90.65
# 3                                      90.65
#
#    Pd(0)-ligand_vib_42_standard_rot_strength  Pd(0)-ligand_atom1_%VBur  \
# 0                                    18.6401                  0.936319
# 1                                    18.6401                  0.933984
# 2                                    18.6401                  0.927517
# 3                                    18.6401                  0.887309
#
#    Pd(0)-ligand_atom2_%VBur  Pd(0)-ligand_atom3_%VBur  \
# 0                  0.878956                  0.939223
# 1                  0.878447                  0.860573
# 2                  0.878537                  0.859076
# 3                  0.843957                  0.819377
#
#    Pd(0)-ligand_atom4_%VBur  Pd(0)-ligand_c_min_%VBur  \
# 0                  0.930032                  0.768390
# 1                  0.872459                  0.764947
# 2                  0.867459                  0.612048
# 3                  0.826712                  0.545074
#
#    Pd(0)-ligand_c_min+1_%VBur  Pd(0)-ligand_c_max_%VBur  \
# 0                    0.724799                  0.936319
# 1                    0.723691                  0.933984
# 2                    0.608485                  0.927517
# 3                    0.550493                  0.887309
#
#    Pd(0)-ligand_c_max-1_%VBur
# 0                    0.779468
# 1                    0.778689
# 2                    0.531391
# 3                    0.534056
#
# [4 rows x 685 columns]

# %% [markdown]
# Next, we define dictionaries for the reaction parameters, type of encoding, and external descriptors. Note that the corresponding keys need to match across the three dictionaries. We are going to pass these objects to the main BO class which will automatically build a search space.
#
# The reaction space generation method can also be used to:
# -	One-hot-encode descriptors: ```encoding={…, ‘parameter’:‘ohe’, …}```
# -	Compute Mordred fingerprints from SMILES strings: ```encoding={…, ‘parameter’:‘mordred’, …}```
# -	Look up chemical names from the NIH database: ```encoding={…, ‘parameter’:’resolve’, …}```

# %%
# Parameters in reaction space

components = {'aryl_halid':'DFT',                             # DFT descriptors
              'additive':'DFT',                                    # DFT descriptors
              'base':'DFT',                                      # DFT descriptors
              'ligand':'DFT',
              }                    # Discrete grid of temperatures



# External descriptor matrices override specified encoding

dft = {'aryl_halid':aryl_halid.data,                          # Unprocessed descriptor DataFrame
       'additive':additive.data,                                 # Unprocessed descriptor DataFrame
       'base':base.data,
       'ligand':ligand.data}                                     # Unprocessed descriptor DataFrame

# %% [markdown]
# ## Instantiating EDBO
#
# EDBO has methods for automatically generating the search space from the components above. For example, when you instantiate a new ```edbo.bro.BO_express``` object (which is a more user friendly super class of ```edbo.bro.BO```) it will automatically parse parameters (e.g., look up chemical names from NIH database), compute descriptors (e.g., OHE or Mordred), and generate an encoded combinatorial set of all experiments. After generating the encoded search space it will also take care of any necessary pre-processing steps (e.g., normalization, de-correlation, etc.).
#
# The main BO class has a lot of keyword arguments (some of which are shown below). The preset parameters should work pretty well for most problems which means that all you really need to do in order to start an optimization is:
# -	Pass the search space
# -	Choose a batch size
#
# In this example, ```edbo.bro.BO_express``` actually attempts to automatically choose model priors to match the data type. In order to be consistent with the paper, here we will reset the priors directly after instantiation.

# %%
from edbo.bro import BO_express

# BO object

bo = BO_express(components,                                 # Reaction parameters
                                          # Encoding specification
                descriptor_matrices=dft,                    # DFT descriptors
                acquisition_function='EI',                  # Use expectation value of improvement
                init_method='rand',                         # Use random initialization
                batch_size=10,                              # 10 experiments per round
                target='yield')                             # Optimize yield

# BO_express actually automatically chooses priors
# We can reset them manually to make sure they match the ones from our paper

from gpytorch.priors import GammaPrior

bo.lengthscale_prior = [GammaPrior(2.0, 0.2), 5.0]
bo.outputscale_prior = [GammaPrior(5.0, 0.5), 8.0]
bo.noise_prior = [GammaPrior(1.5, 0.5), 1.0]

# %% [markdown]
# The parameterized domain is held as a ```pandas.DataFrame``` in the objective module.

# %%
bo.obj.domain.head()
# Out:
#    aryl_halide_number_of_atoms  aryl_halide_dipole  aryl_halide_molar_mass  \
# 0                          1.0            0.525088                0.451318
# 1                          1.0            0.525088                0.451318
# 2                          1.0            0.525088                0.451318
# 3                          1.0            0.525088                0.451318
# 4                          1.0            0.525088                0.451318
#
#    aryl_halide_molar_volume  aryl_halide_electronic_spatial_extent  \
# 0                  0.568953                               0.657157
# 1                  0.568953                               0.657157
# 2                  0.568953                               0.657157
# 3                  0.568953                               0.657157
# 4                  0.568953                               0.657157
#
#    aryl_halide_homo_energy  aryl_halide_lumo_energy  aryl_halide_hardness  \
# 0                 0.666379                 0.998265              0.909383
# 1                 0.666379                 0.998265              0.909383
# 2                 0.666379                 0.998265              0.909383
# 3                 0.666379                 0.998265              0.909383
# 4                 0.666379                 0.998265              0.909383
#
#    aryl_halide_E_scf  aryl_halide_ES_root_dipole  ...  \
# 0           0.089682                         0.0  ...
# 1           0.089682                         0.0  ...
# 2           0.089682                         0.0  ...
# 3           0.089682                         0.0  ...
# 4           0.089682                         0.0  ...
#
#    Pd(0)-ligand_vib_7_reduced_mass  Pd(0)-ligand_vib_11_dip_strength  \
# 0                         1.000000                          0.698658
# 1                         0.582988                          0.580000
# 2                         0.711462                          1.000000
# 3                         0.000000                          0.000000
# 4                         1.000000                          0.698658
#
#    Pd(0)-ligand_vib_14_reduced_mass  Pd(0)-ligand_vib_14_rot_strength  \
# 0                          0.260280                          0.774294
# 1                          1.000000                          0.007232
# 2                          0.283746                          1.000000
# 3                          0.000000                          0.000000
# 4                          0.260280                          0.774294
#
#    Pd(0)-ligand_vib_15_reduced_mass  Pd(0)-ligand_vib_16_frequency  \
# 0                          0.000000                       0.000000
# 1                          0.170316                       0.431794
# 2                          1.000000                       0.662341
# 3                          0.355231                       1.000000
# 4                          0.000000                       0.000000
#
#    Pd(0)-ligand_vib_20_reduced_mass  Pd(0)-ligand_vib_29_rot_strength  \
# 0                          1.000000                          0.377417
# 1                          0.026728                          0.000000
# 2                          0.000000                          1.000000
# 3                          0.395910                          0.502986
# 4                          1.000000                          0.377417
#
#    Pd(0)-ligand_vib_30_reduced_mass  Pd(0)-ligand_vib_35_rot_strength
# 0                          0.000000                          1.000000
# 1                          1.000000                          0.000000
# 2                          0.137210                          0.813280
# 3                          0.145733                          0.320248
# 4                          0.000000                          1.000000
#
# [5 rows x 260 columns]

# %% [markdown]
# For ```edbo.bro.BO_express```, information about the reaction not directly relevant to the BO algorithm is held in a reaction data container. For example, the corresponding unencoded domain points.

# %%
bo.reaction.get_experiments([0,1,2,3,4])
# Out:
#   aryl_halide_CAS_Number_index additive_CAS_Number_index  \
# 0                    1585-07-5                  300-87-8
# 1                    1585-07-5                  300-87-8
# 2                    1585-07-5                  300-87-8
# 3                    1585-07-5                  300-87-8
# 4                    1585-07-5                  300-87-8
#
#   base_CAS_Number_index Pd(0)-ligand_CAS_Number_index
# 0            29166-72-1                  1445972-29-1
# 1            29166-72-1                  1536473-72-9
# 2            29166-72-1                  1447963-75-8
# 3            29166-72-1                  1445085-55-1
# 4            84030-20-6                  1445972-29-1

# %% [markdown]
# The reaction object also has other useful methods. For example, visualize the chemical structures corresponding to a given experiment.

# %%
bo.reaction.visualize(0)
# Out:
# ##################################################### Experiment
#
#    aryl_halide_CAS_Number_index additive_CAS_Number_index  \
# 0                    1585-07-5                  300-87-8
#
#   base_CAS_Number_index Pd(0)-ligand_CAS_Number_index
# 0            29166-72-1                  1445972-29-1
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# ~\AppData\Local\Temp;\ipykernel_21216\3348692841.py in <module>
# ----> 1 bo.reaction.visualize(0)
#
# c:\Users\TERRIEAI\Anaconda3\envs\edbo\lib\site-packages\edbo\utils.py in visualize(self, experiment_index_value, svg)
#      82               '\n')
#      83
# ---> 84         return cd.show()
#      85
#      86     def get_experiments(self, index_values):
#
# c:\Users\TERRIEAI\Anaconda3\envs\edbo\lib\site-packages\edbo\chem_utils.py in show(self)
#      97                     highlightAtomLists=None,
#      98                     highlightBondLists=None,
# ---> 99                     useSVG=self.SVG)
#     100
#     101         display.display(img)
#
# c:\Users\TERRIEAI\Anaconda3\envs\edbo\lib\site-packages\rdkit\Chem\Draw\IPythonConsole.py in ShowMols(mols, maxMols, **kwargs)
#     195       if prop in kwargs:
#     196         kwargs[prop] = kwargs[prop][:maxMols]
# --> 197   res = fn(mols, drawOptions=drawOptions, **kwargs)
#     198   if kwargs['useSVG']:
#     199     return SVG(res)
#
# c:\Users\TERRIEAI\Anaconda3\envs\edbo\lib\site-packages\rdkit\Chem\Draw\__init__.py in MolsToGridImage(mols, molsPerRow, subImgSize, legends, highlightAtomLists, highlightBondLists, useSVG, returnPNG, **kwargs)
#     568     return _MolsToGridSVG(mols, molsPerRow=molsPerRow, subImgSize=subImgSize, legends=legends,
#     569                           highlightAtomLists=highlightAtomLists,
# --> 570                           highlightBondLists=highlightBondLists, **kwargs)
#     571   else:
#     572     return _MolsToGridImage(mols, molsPerRow=molsPerRow, subImgSize=subImgSize, legends=legends,
#
# c:\Users\TERRIEAI\Anaconda3\envs\edbo\lib\site-packages\rdkit\Chem\Draw\__init__.py in _MolsToGridSVG(mols, molsPerRow, subImgSize, legends, highlightAtomLists, highlightBondLists, drawOptions, **kwargs)
#     531     legends = [''] * len(mols)
#     532
# --> 533   nRows = len(mols) // molsPerRow
#     534   if len(mols) % molsPerRow:
#     535     nRows += 1
#
# ZeroDivisionError: integer division or modulo by zero

# %% [markdown]
# ## Initialization
#
# In keeping with our paper, we will start the optimization campaign by randomly selecting experiments. We made this choice when we instantiated the optimizer when we specified ```init_method='rand'```. We can then export the proposed experiments to a CSV file and fill in the results once we run the experiments.

# %%
bo.init_sample(seed=0)             # Initialize
bo.export_proposed('init.csv')     # Export design to a CSV file
bo.get_experiments()               # Print selected experiments
# Out:
#      aryl_halide_CAS_Number_index additive_CAS_Number_index  \
# 569                      402-43-7                15055-81-9
# 1768                     109-04-6                 1006-65-1
# 2543                     626-60-8                 1006-65-1
# 2768                    1120-90-7                  271-58-9
# 1802                     109-04-6                  271-58-9
# 1942                     109-09-1                 1008-75-9
# 1129                      98-56-6               517870-23-4
# 619                      622-98-0                 1006-65-1
# 2043                     109-09-1                51135-73-0
# 692                      622-98-0                 3209-72-1
#
#      base_CAS_Number_index Pd(0)-ligand_CAS_Number_index
# 569             84030-20-6                  1536473-72-9
# 1768            84030-20-6                  1445972-29-1
# 2543           165535-45-5                  1445085-55-1
# 2768           165535-45-5                  1445972-29-1
# 1802            29166-72-1                  1447963-75-8
# 1942           165535-45-5                  1447963-75-8
# 1129            29166-72-1                  1536473-72-9
# 619             84030-20-6                  1445085-55-1
# 2043            29166-72-1                  1445085-55-1
# 692            165535-45-5                  1445972-29-1

# %% [markdown]
# Since we ran this optimization over a few days it was advantageous to save the BO instance for later. That way we didn't have to rebuild the reaction space and reinstantiate the BO object if we close the kernel. The ```edbo.bro.BO.save()``` method will pickle the optimizer for later.

# %%
bo.save()

# %% [markdown]
# Once we have saved the optimizer workspace we can load it by calling ```edbo.bro.BO.load()```.

# %%
from edbo.bro import BO_express

bo = BO_express()
bo.load()

# %% [markdown]
# ## Bayesian Optimization Loop
#
# Now that we have defined the reaction space and optimizer, we can iteratively run the optimizer to select experiments, evaluate the experiments in the lab, and read in the results as CSV files. In this case, we ran the experiments selected at random above. We can load the data using the ```edbo.bro.BO_express.add_results``` method.

# %%
bo.add_results('results/init.csv')

# %% [markdown]
# Next in the BO loop, we fit the surrogate model (by default ```edbo.models.GP_Model```) and optimize the acquisition function (we selected expected improvement at instantiation with ```acquisition_function='EI'```) to select the next experiments to run. This is accomplished with the ```edbo.bro.BO.run``` method. This method returns the encoded domain points for the selected experiments and stores them in ```edbo.bro.BO.proposed_experiments```.

# %%
bo.run()
# Out:
#         azadicarboxylate_number_of_atoms_MING  azadicarboxylate_dipole_MING  \
# 155999                               0.000000                      0.000216
# 65878                                0.857143                      1.000000
# 155500                               0.000000                      0.000216
# 125879                               1.000000                      0.000000
# 153379                               0.000000                      0.000216
# 155379                               0.000000                      0.000216
# 5875                                 0.714286                      0.000096
# 155895                               0.000000                      0.000216
# 155879                               0.000000                      0.000216
# 155975                               0.000000                      0.000216
#
#         azadicarboxylate_dipole_Boltz  azadicarboxylate_molar_mass_MING  \
# 155999                       0.000000                          0.000000
# 65878                        1.000000                          1.000000
# 155500                       0.000000                          0.000000
# 125879                       0.092534                          0.410916
# 153379                       0.000000                          0.000000
# 155379                       0.000000                          0.000000
# 5875                         0.655230                          0.297828
# 155895                       0.000000                          0.000000
# 155879                       0.000000                          0.000000
# 155975                       0.000000                          0.000000
#
#         azadicarboxylate_molar_volume_MING  azadicarboxylate_lumo_energy_MING  \
# 155999                            0.000000                           0.782918
# 65878                             1.000000                           0.000000
# 155500                            0.000000                           0.782918
# 125879                            0.721708                           1.000000
# 153379                            0.000000                           0.782918
# 155379                            0.000000                           0.782918
# 5875                              0.583642                           0.748221
# 155895                            0.000000                           0.782918
# 155879                            0.000000                           0.782918
# 155975                            0.000000                           0.782918
#
#         azadicarboxylate_hardness_MING  azadicarboxylate_hardness_Boltz  \
# 155999                        0.002144                         0.000000
# 65878                         0.369550                         0.447016
# 155500                        0.002144                         0.000000
# 125879                        0.000000                         0.135560
# 153379                        0.002144                         0.000000
# 155379                        0.002144                         0.000000
# 5875                          1.000000                         1.000000
# 155895                        0.002144                         0.000000
# 155879                        0.002144                         0.000000
# 155975                        0.002144                         0.000000
#
#         azadicarboxylate_E_scf_MING  \
# 155999                     1.000000
# 65878                      0.000000
# 155500                     1.000000
# 125879                     0.826069
# 153379                     1.000000
# 155379                     1.000000
# 5875                       0.853246
# 155895                     1.000000
# 155879                     1.000000
# 155975                     1.000000
#
#         azadicarboxylate_ES_root_molar_volume_MING  ...  \
# 155999                                    0.000000  ...
# 65878                                     0.954961  ...
# 155500                                    0.000000  ...
# 125879                                    1.000000  ...
# 153379                                    0.000000  ...
# 155379                                    0.000000  ...
# 5875                                      0.378844  ...
# 155895                                    0.000000  ...
# 155879                                    0.000000  ...
# 155975                                    0.000000  ...
#
#         solvent_c_min+1_NMR_shift  solvent_c_max_Mulliken_charge  \
# 155999                   1.000000                       0.000000
# 65878                    1.000000                       0.000000
# 155500                   1.000000                       0.000000
# 125879                   1.000000                       0.000000
# 153379                   1.000000                       0.000000
# 155379                   0.961782                       0.584865
# 5875                     1.000000                       0.000000
# 155895                   1.000000                       0.000000
# 155879                   1.000000                       0.000000
# 155975                   1.000000                       0.000000
#
#         solvent_c_max_NMR_shift  solvent_c_max_ES_root_Mulliken_charge  \
# 155999                 1.000000                               0.000000
# 65878                  1.000000                               0.000000
# 155500                 1.000000                               0.000000
# 125879                 1.000000                               0.000000
# 153379                 1.000000                               0.000000
# 155379                 0.126492                               0.404132
# 5875                   1.000000                               0.000000
# 155895                 1.000000                               0.000000
# 155879                 1.000000                               0.000000
# 155975                 1.000000                               0.000000
#
#         solvent_c_min_%VBur  solvent_c_min+1_%VBur  substrate_concentration  \
# 155999             0.721064               0.745407                      1.0
# 65878              0.721064               0.745407                      1.0
# 155500             0.721064               0.745407                      0.0
# 125879             0.721064               0.745407                      1.0
# 153379             0.721064               0.745407                      1.0
# 155379             0.028900               1.000000                      1.0
# 5875               0.721064               0.745407                      1.0
# 155895             0.721064               0.745407                      1.0
# 155879             0.721064               0.745407                      1.0
# 155975             0.721064               0.745407                      1.0
#
#         azadicarb_equiv  phos_equiv  temperature
# 155999              1.0         1.0         1.00
# 65878               0.0         0.0         0.75
# 155500              0.0         0.0         0.00
# 125879              0.0         0.0         1.00
# 153379              0.0         0.0         1.00
# 155379              0.0         0.0         1.00
# 5875                0.0         0.0         0.00
# 155895              0.0         1.0         0.00
# 155879              0.0         0.0         1.00
# 155975              1.0         0.0         0.00
#
# [10 rows x 278 columns]

# %% [markdown]
# Once we have used the run method, we can carry out miscellaneous analysis using some built in methods. For example, we can track the convergence of the optimizer (obviously not interesting here).

# %%
bo.plot_convergence()

# %% [markdown]
# We can see how well the surrogate model fits the available data.

# %%
bo.model.regression()

# %% [markdown]
# We can also crack open the optimizer and check out what is happening under the hood by writing some custom analysis functions. For example, we can plot a 1D projection of the parallel acquisition function's choices (For EI batching is accplished with ```edbo.acq_func.Kriging_believer```).

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_kb_projections(n=2):
    """
    Plot 1D projection of Kriging believer parallel batch selection algorithm.
    """

    fig, ax = plt.subplots(len(bo.acq.function.projections[:n]),1, figsize=(12, n * 12 / 5))
    for i, p in enumerate(bo.acq.function.projections[:n]):
        ax[i].plot(range(len(p)), p, color='C' + str(i))
        ax[i].plot([np.argmax(p)], p[np.argmax(p)], 'X', markersize=10, color='black')
        ax[i].set_xlabel('X')
        ax[i].set_ylabel('EI')
        ax[i].set_title('Kriging Believer Projection:' + str(i))
    
    plt.tight_layout()
    plt.show()
    
plot_kb_projections()

# %% [markdown]
# Back to the main task – optimizing this Mitsunobu reaction. Now we can export the next round of experiments as a CSV file, run the experiments, fill in the CSV, and iterate.

# %%
bo.export_proposed('round0.csv')

# %% [markdown]
# Let's say we are happy with this workflow and want to carry out the same analysis in each round. We can wrap each of these steps up into a simple function.

# %%
def workflow(export_path):
    """
    Function for our BO pipeline.
    """
    
    bo.run()
    bo.plot_convergence()
    bo.model.regression()
    plot_kb_projections()
    bo.export_proposed(export_path)

# %% [markdown]
# And run the same analysis for each round.

# %%
bo.add_results('results/round0.csv')       # Load real results from our experiments
workflow('round1.csv')                     # Run the workflow and export the next experiments to 'round1.csv'

# %%
bo.add_results('results/round1.csv')       # Load real results from our experiments
workflow('round2.csv')                     # Run the workflow and export the next experiments to 'round2.csv'

# %%
bo.add_results('results/round2.csv')       # Load real results from our experiments
workflow('round3.csv')                     # Run the workflow and export the next experiments to 'round3.csv'

# %% [markdown]
# Awesome, so in 4 rounds of 10 experiments we have hit essentially quantitative yield for this reaction. Once you have the data you can do whatever analysis your heart desires. Let’s just check out the conditions for the best yielding reactions.

# %%
results = pd.DataFrame(columns=bo.reaction.index_headers + ['yield'])
for path in ['init', 'round0', 'round1', 'round2']:
    results = pd.concat([results, pd.read_csv('results/' + path + '.csv', index_col=0)], sort=False)

results = results.sort_values('yield', ascending=False)
results.head()
# Out:
#           azadicarboxylate_SMILES_index      phosphine_SMILES_index  \
# 125997  O=C(N1CCCCC1)/N=N/C(N2CCCCC2)=O  CP(C1=CC=CC=C1)C2=CC=CC=C2
# 156374        CN(C(/N=N/C(N(C)C)=O)=O)C  CP(C1=CC=CC=C1)C2=CC=CC=C2
# 125874  O=C(N1CCCCC1)/N=N/C(N2CCCCC2)=O  CP(C1=CC=CC=C1)C2=CC=CC=C2
# 127499  O=C(N1CCCCC1)/N=N/C(N2CCCCC2)=O  CP(C1=CC=CC=C1)C2=CC=CC=C2
# 155974        CN(C(/N=N/C(N(C)C)=O)=O)C  CP(C1=CC=CC=C1)C2=CC=CC=C2
#
#        solvent_SMILES_index  substrate_concentration_index  \
# 125997              C1CCOC1                           0.20
# 156374                 CC#N                           0.15
# 125874              C1CCOC1                           0.15
# 127499            CC(OCC)=O                           0.20
# 155974              C1CCOC1                           0.20
#
#         azadicarb_equiv_index  phos_equiv_index temperature_index      yield
# 125997                    1.9               1.9                25  98.786244
# 156374                    1.9               1.9                45  98.747640
# 125874                    1.9               1.9                45  98.531481
# 127499                    1.9               1.9                45  97.435627
# 155974                    1.7               1.9                45  97.256471

# %% [markdown]
# Plot a bar chart for parameter frequency in the top 5 yielding reactions.

# %%
fig, ax = plt.subplots(1, len(results.columns.values[:-1]), figsize=(30,5))

for i, feature  in enumerate(results.columns.values[:-1]):
    results[feature].iloc[:5].value_counts().plot(kind="bar", ax=ax[i]).set_title(feature)
plt.show()

# %% [markdown]
# Visualize the reagents in the top 5 yielding reactions using ```edbo.chem_utils.ChemDraw```.

# %%
from edbo.chem_utils import ChemDraw

for col in results.iloc[:,:3].columns.values:
    print('\nComponent:', col, '\n')
    cdx = ChemDraw(results[col].iloc[:5].drop_duplicates())
    cdx.show()
# Out:
# Component: azadicarboxylate_SMILES_index
# Component: phosphine_SMILES_index
# Component: solvent_SMILES_index

# %% [markdown]
# Total compute time on my laptop (i7-6500U): 8 min 38 s
